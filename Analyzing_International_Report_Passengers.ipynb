# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("International_Report_Passengers.csv")

# %%
df.columns
# Out:
# Index(['data_dte', 'Year', 'Month', 'usg_apt_id', 'usg_apt', 'usg_wac',
#        'fg_apt_id', 'fg_apt', 'fg_wac', 'airlineid', 'carrier', 'carriergroup',
#        'type', 'Scheduled', 'Charter', 'Total'],
#       dtype='object')

# %%
#Checking for nulls
df.isna().sum()
# Out:
# data_dte           0
# Year               0
# Month              0
# usg_apt_id         0
# usg_apt            0
# usg_wac            0
# fg_apt_id          0
# fg_apt             0
# fg_wac             0
# airlineid          0
# carrier         1547
# carriergroup       0
# type               0
# Scheduled          0
# Charter            0
# Total              0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# data_dte        0
# Year            0
# Month           0
# usg_apt_id      0
# usg_apt         0
# usg_wac         0
# fg_apt_id       0
# fg_apt          0
# fg_wac          0
# airlineid       0
# carrier         0
# carriergroup    0
# type            0
# Scheduled       0
# Charter         0
# Total           0
# dtype: int64

# %% [markdown]
# Nulls Removed Successfully !

# %%
#Checking for Duplicates
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 284688    False
# 284689    False
# 284690    False
# 284691    False
# 284692    False
# Length: 283146, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No Duplicates

# %%
column_types=df.dtypes

# %%
categorical_features=column_types[column_types==object]

# %%
categorical_features
# Out:
# data_dte    object
# usg_apt     object
# fg_apt      object
# carrier     object
# type        object
# dtype: object

# %%
Dummies=pd.get_dummies(df["carrier"],df["data_dte"],df["usg_apt"])

# %%
Dummies.value_counts()
# Out:
# 0         05/01/2014\n1         06/01/2007\n2         12/01/2005\n3         04/01/2003\n4         12/01/2005\n             ...    \n284688    12/01/1990\n284689    12/01/2003\n284690    04/01/1990\n284691    09/01/2001\n284692    06/01/2007\nName: data_dte, Length: 283146, dtype: object0         RDU\n1         MCO\n2         DTW\n3         MSP\n4         GUM\n         ... \n284688    RDU\n284689    DCA\n284690    IAH\n284691    ORD\n284692    PDX\nName: usg_apt, Length: 283146, dtype: object02Q  0         05/01/2014\n1         06/01/2007\n2         12/01/2005\n3         04/01/2003\n4         12/01/2005\n             ...    \n284688    12/01/1990\n284689    12/01/2003\n284690    04/01/1990\n284691    09/01/2001\n284692    06/01/2007\nName: data_dte, Length: 283146, dtype: object0         RDU\n1         MCO\n2         DTW\n3         MSP\n4         GUM\n         ... \n284688    RDU\n284689    DCA\n284690    IAH\n284691    ORD\n284692    PDX\nName: usg_apt, Length: 283146, dtype: object0
# ...

# %%
df.head()
# Out:
#      data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0  05/01/2014  2014      5       14492     RDU       36      11032    CUN
# 1  06/01/2007  2007      6       13204     MCO       33      16085    YHZ
# 2  12/01/2005  2005     12       11433     DTW       43      10411    AUA
# 3  04/01/2003  2003      4       13487     MSP       63      16304    ZIH
# 4  12/01/2005  2005     12       12016     GUM        5      11138    CRK
#
#    fg_wac  airlineid carrier  carriergroup        type  Scheduled  Charter  \
# 0     148      19534      AM             0  Passengers          0      315
# 1     951      20364      C6             0  Passengers          0      683
# 2     277      20344      RD             1  Passengers          0     1010
# 3     148      20204      MG             1  Passengers          0      508
# 4     766      20312      TZ             1  Passengers          0       76
#
#    Total
# 0    315
# 1    683
# 2   1010
# 3    508
# 4     76

# %%
df.describe()
# Out:
#                 Year          Month     usg_apt_id        usg_wac  \
# count  283146.000000  283146.000000  283146.000000  283146.000000
# mean     2005.226032       6.251397   12868.894570      42.838617
# std         8.828001       3.486994    3609.357315      26.972310
# min      1990.000000       1.000000   10010.000000       1.000000
# 25%      1997.000000       3.000000   11618.000000      22.000000
# 50%      2005.000000       6.000000   12892.000000      33.000000
# 75%      2013.000000       9.000000   13930.000000      72.000000
# max      2020.000000      12.000000   99999.000000      93.000000
#
#            fg_apt_id         fg_wac      airlineid   carriergroup  \
# count  283146.000000  283146.000000  283146.000000  283146.000000
# mean    13647.091289     446.783525   20178.941666       0.600118
# std      2027.161211     311.939730     551.522694       0.489875
# min     10125.000000     106.000000   19386.000000       0.000000
# ...

# %%
#Checking for Outliers
x=df['Month']
plt.boxplot(x)
plt.show()

# %%
plt.hist(df['Year'],cumulative=True)
plt.grid(True)
plt.show()

# %%
plt.scatter(df['Year'],df['fg_apt_id'])
plt.show()

# %%
#Normalizing
df['fg_apt_id']=(df['fg_apt_id']-df['fg_apt_id'].mean())/df['fg_apt_id'].std()

# %%
df.head()
# Out:
#      data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0  05/01/2014  2014      5       14492     RDU       36  -1.290026    CUN
# 1  06/01/2007  2007      6       13204     MCO       33   1.202622    YHZ
# 2  12/01/2005  2005     12       11433     DTW       43  -1.596366    AUA
# 3  04/01/2003  2003      4       13487     MSP       63   1.310655    ZIH
# 4  12/01/2005  2005     12       12016     GUM        5  -1.237736    CRK
#
#    fg_wac  airlineid carrier  carriergroup        type  Scheduled  Charter  \
# 0     148      19534      AM             0  Passengers          0      315
# 1     951      20364      C6             0  Passengers          0      683
# 2     277      20344      RD             1  Passengers          0     1010
# 3     148      20204      MG             1  Passengers          0      508
# 4     766      20312      TZ             1  Passengers          0       76
#
#    Total
# 0    315
# 1    683
# 2   1010
# 3    508
# 4     76
